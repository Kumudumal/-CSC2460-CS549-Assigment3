# %%
# !pip install ultralytics roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 29.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 12.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 98.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 96.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="kyMWl2OBrol1fg8V1ykM")
project = rf.workspace("kumu").project("player-tracking-hndig")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to player-tracking-2 in yolov8:: 100%|██████████| 568/568 [00:00<00:00, 8993.08it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from ultralytics import YOLO

# load pretrained small model
model = YOLO("yolov8s.pt")

# start training
model.train(
    data="/content/player-tracking-2/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
    device=0
)
# Out:
# ...
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !zip -r yolo8s_results.zip /content/runs/detect/train
# Out:
#   adding: content/runs/detect/train/ (stored 0%)
#   adding: content/runs/detect/train/train_batch0.jpg (deflated 4%)
#   adding: content/runs/detect/train/labels.jpg (deflated 36%)
#   adding: content/runs/detect/train/BoxR_curve.png (deflated 17%)
#   adding: content/runs/detect/train/args.yaml (deflated 52%)
#   adding: content/runs/detect/train/train_batch642.jpg (deflated 7%)
#   adding: content/runs/detect/train/BoxP_curve.png (deflated 17%)
#   adding: content/runs/detect/train/confusion_matrix.png (deflated 37%)
#   adding: content/runs/detect/train/BoxPR_curve.png (deflated 23%)
#   adding: content/runs/detect/train/weights/ (stored 0%)
#   adding: content/runs/detect/train/weights/best.pt (deflated 8%)
#   adding: content/runs/detect/train/weights/last.pt (deflated 8%)
#   adding: content/runs/detect/train/train_batch1.jpg (deflated 3%)
#   adding: content/runs/detect/train/val_batch0_pred.jpg (deflated 7%)
# ...

# %%
from ultralytics import YOLO

# load your trained weights
model = YOLO("/content/runs/detect/train/weights/best.pt")

# run detection
results = model.predict(
    source="/content/football.1.mp4",
    conf=0.25,
    save=True
)

print("Video processed!")
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/993) /content/football.1.mp4: 384x640 1 player, 47.3ms
# video 1/1 (frame 2/993) /content/football.1.mp4: 384x640 1 player, 10.7ms
# video 1/1 (frame 3/993) /content/football.1.mp4: 384x640 1 player, 10.7ms
# video 1/1 (frame 4/993) /content/football.1.mp4: 384x640 1 player, 10.7ms
# video 1/1 (frame 5/993) /content/football.1.mp4: 384x640 1 player, 10.7ms
# ...
