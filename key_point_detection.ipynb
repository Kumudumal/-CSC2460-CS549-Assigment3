# %%
# !pip install ultralytics opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 13.2 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import cv2

# Load pretrained pose model
model = YOLO("yolov8n-pose.pt")

# Run pose detection
results = model("cricket.1.mp4", save=True)

print("Pose estimation completed")
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/693) /content/cricket.1.mp4: 384x640 5 persons, 631.8ms
# video 1/1 (frame 2/693) /content/cricket.1.mp4: 384x640 5 persons, 161.6ms
# video 1/1 (frame 3/693) /content/cricket.1.mp4: 384x640 5 persons, 157.1ms
# video 1/1 (frame 4/693) /content/cricket.1.mp4: 384x640 5 persons, 150.6ms
# video 1/1 (frame 5/693) /content/cricket.1.mp4: 384x640 5 persons, 165.8ms
# ...
